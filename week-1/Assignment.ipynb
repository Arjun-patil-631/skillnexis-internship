# %%
#assignment-1
import pandas as pd
df=pd.read_csv('employee.csv')
df.info()
df.describe()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   EmployeeID  100 non-null    int64
#  1   Age         90 non-null     float64
#  2   Gender      100 non-null    object
#  3   City        94 non-null     object
#  4   Department  100 non-null    object
#  5   Experience  100 non-null    int64
#  6   Salary      92 non-null     float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 5.6+ KB
#        EmployeeID        Age  Experience         Salary
# count  100.000000  90.000000  100.000000      92.000000
# mean    50.500000  32.833333   10.050000   76021.630435
# std     29.011492   6.988353    5.696667   28065.394183
# min      1.000000  22.000000    0.000000   30053.000000
# 25%     25.750000  27.000000    6.000000   50119.750000
# 50%     50.500000  33.000000   10.000000   76942.500000
# 75%     75.250000  39.000000   15.000000  101019.000000
# max    100.000000  45.000000   20.000000  119399.000000

# %%
#assignment-2
#To handle missing values using mean/median imputation

import pandas as pd
df=pd.read_csv('employee.csv')

#checking values
print(df.isnull().sum())

#fill the missing values
df["Age"]=df["Age"].fillna(df["Age"].median())
df["Salary"]=df["Salary"].fillna(df["Salary"].mean())

#fill categorical missing values
df["City"]=df["City"].fillna(df["City"].mode()[0])

print("\nMissing values after imputation:")
print(df.isnull().sum())
# Out:
# EmployeeID     0
# Age           10
# Gender         0
# City           6
# Department     0
# Experience     0
# Salary         8
# dtype: int64
#
# Missing values after imputation:
# EmployeeID    0
# Age           0
# Gender        0
# City          0
# Department    0
# Experience    0
# Salary        0
# dtype: int64

# %%
#Assignment -3
import pandas as pd
from sklearn.preprocessing import LabelEncoder

df=pd.read_csv('employee.csv')

le=LabelEncoder()
df["Gender"]=le.fit_transform(df["Gender"])

print(df.head())
# Out:
#    EmployeeID   Age  Gender       City Department  Experience    Salary
# 0           1  42.0       1       Pune         HR           3   33278.0
# 1           2  26.0       0     Mumbai         IT           3  118696.0
# 2           3  23.0       1  Bengaluru         HR           0   42280.0
# 3           4  39.0       1     Mumbai      Sales           6  115181.0
# 4           5  36.0       0  Hyderabad         HR          18   66463.0

# %%
df=pd.get_dummies(df, 
                  columns=["City", "Department"],
                  drop_first=True)
print(df.head())
# Out:
#    EmployeeID   Age  Gender  Experience    Salary  City_Chennai  \
# 0           1  42.0       1           3   33278.0         False
# 1           2  26.0       0           3  118696.0         False
# 2           3  23.0       1           0   42280.0         False
# 3           4  39.0       1           6  115181.0         False
# 4           5  36.0       0          18   66463.0         False
#
#    City_Hyderabad  City_Mumbai  City_Pune  Department_HR  Department_IT  \
# 0           False        False       True           True          False
# 1           False         True      False          False           True
# 2           False        False      False           True          False
# 3           False         True      False          False          False
# 4            True        False      False           True          False
#
#    Department_Marketing  Department_Sales
# 0                 False             False
# 1                 False             False
# 2                 False             False
# 3                 False              True
# 4                 False             False

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   EmployeeID            100 non-null    int64
#  1   Age                   90 non-null     float64
#  2   Gender                100 non-null    int64
#  3   Experience            100 non-null    int64
#  4   Salary                92 non-null     float64
#  5   City_Chennai          100 non-null    bool
#  6   City_Hyderabad        100 non-null    bool
#  7   City_Mumbai           100 non-null    bool
#  8   City_Pune             100 non-null    bool
#  9   Department_HR         100 non-null    bool
#  10  Department_IT         100 non-null    bool
#  11  Department_Marketing  100 non-null    bool
#  12  Department_Sales      100 non-null    bool
# dtypes: bool(8), float64(2), int64(3)
# memory usage: 4.8 KB
